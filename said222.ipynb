# %%
import pandas as pd

dataTrain = pd.read_csv('E:\said Assignment\CarPrice_Assignment.csv')

dataTrain.head()
# Out:
#    symboling                   CarName fueltype      carbody drivewheel  \
# 0          3        alfa-romero giulia      gas  convertible        rwd
# 1          3       alfa-romero stelvio      gas  convertible        rwd
# 2          1  alfa-romero Quadrifoglio      gas    hatchback        rwd
# 3          2               audi 100 ls      gas        sedan        fwd
# 4          2                audi 100ls      gas        sedan        4wd
#
#   enginelocation  wheelbase  carlength  carwidth  carheight  curbweight  \
# 0          front       88.6      168.8      64.1       48.8        2548
# 1          front       88.6      168.8      64.1       48.8        2548
# 2          front       94.5      171.2      65.5       52.4        2823
# 3          front       99.8      176.6      66.2       54.3        2337
# 4          front       99.4      176.6      66.4       54.3        2824
#
#   enginetype cylindernumber  enginesize  boreratio  stroke  compressionratio  \
# 0       dohc           four         130       3.47    2.68               9.0
# 1       dohc           four         130       3.47    2.68               9.0
# 2       ohcv            six         152       2.68    3.47               9.0
# 3        ohc           four         109       3.19    3.40              10.0
# 4        ohc           five         136       3.19    3.40               8.0
#
#    horsepower    price
# 0         111  13495.0
# 1         111  16500.0
# 2         154  16500.0
# 3         102  13950.0
# 4         115  17450.0

# %%
type(dataTrain)  #data type
# Out:
# pandas.core.frame.DataFrame

# %%
dataTrain.shape # check dimension
# Out:
# (205, 19)

# %%
dataTrain.isnull().sum()
# Out:
# symboling           0
# CarName             0
# fueltype            0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# price               0
# dtype: int64

# %%
dataTrain = dataTrain.dropna()
dataTest = dataTest.dropna()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_15024/376475151.py in <module>
#       1 dataTrain = dataTrain.dropna()
# ----> 2 dataTest = dataTest.dropna()
#
# NameError: name 'dataTest' is not defined

# %%
dataTrain.isnull().sum()
# Out:
# symboling           0
# CarName             0
# fueltype            0
# carbody             0
# drivewheel          0
# enginelocation      0
# wheelbase           0
# carlength           0
# carwidth            0
# carheight           0
# curbweight          0
# enginetype          0
# cylindernumber      0
# enginesize          0
# boreratio           0
# stroke              0
# compressionratio    0
# horsepower          0
# price               0
# dtype: int64

# %%
dataTrain.shape # 15 rows removed
# Out:
# (205, 19)

# %%
dataTrain.dtypes  # checking the data type of every column
# Out:
# symboling             int64
# CarName              object
# fueltype             object
# carbody              object
# drivewheel           object
# enginelocation       object
# wheelbase           float64
# carlength           float64
# carwidth            float64
# carheight           float64
# curbweight            int64
# enginetype           object
# cylindernumber       object
# enginesize            int64
# boreratio           float64
# stroke              float64
# compressionratio    float64
# horsepower            int64
# price               float64
# dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,6))
corr = dataTrain.corr()
##This is a pandas DataFrame method that is used to calculate the correlation between variables in the DataFrame.
sns.heatmap(corr,annot=True)
plt.show()

# %%
dataTrain.describe() #generate various summary statistics of a DataFrame
#Note: Only features with numeric data are considered
# Out:
#         symboling   wheelbase   carlength    carwidth   carheight  \
# count  205.000000  205.000000  205.000000  205.000000  205.000000
# mean     0.834146   98.756585  174.049268   65.907805   53.724878
# std      1.245307    6.021776   12.337289    2.145204    2.443522
# min     -2.000000   86.600000  141.100000   60.300000   47.800000
# 25%      0.000000   94.500000  166.300000   64.100000   52.000000
# 50%      1.000000   97.000000  173.200000   65.500000   54.100000
# 75%      2.000000  102.400000  183.100000   66.900000   55.500000
# max      3.000000  120.900000  208.100000   72.300000   59.800000
#
#         curbweight  enginesize   boreratio      stroke  compressionratio  \
# count   205.000000  205.000000  205.000000  205.000000        205.000000
# mean   2555.565854  126.907317    3.329756    3.255415         10.142537
# std     520.680204   41.642693    0.270844    0.313597          3.972040
# min    1488.000000   61.000000    2.540000    2.070000          7.000000
# 25%    2145.000000   97.000000    3.150000    3.110000          8.600000
# 50%    2414.000000  120.000000    3.310000    3.290000          9.000000
# 75%    2935.000000  141.000000    3.580000    3.410000          9.400000
# max    4066.000000  326.000000    3.940000    4.170000         23.000000
#
#        horsepower         price
# count  205.000000    205.000000
# mean   104.117073  13276.710571
# std     39.544167   7988.852332
# min     48.000000   5118.000000
# 25%     70.000000   7788.000000
# 50%     95.000000  10295.000000
# 75%    116.000000  16503.000000
# max    288.000000  45400.000000

# %%
import matplotlib.pyplot as plt

dataTrain['price'].plot(kind = 'hist', bins = 5, edgecolor='black')   # 5 bins are used
plt.xlabel('Price')
plt.ylabel('Frequency')
plt.title('Distribution of Prices')
plt.show()

# %%
dataTrain.describe(include = 'object') #summary statistics for categorical values
# Out:
#               CarName fueltype carbody drivewheel enginelocation enginetype  \
# count             205      205     205        205            205        205
# unique            147        2       5          3              2          7
# top     toyota corona      gas   sedan        fwd          front        ohc
# freq                6      185      96        120            202        148
#
#        cylindernumber
# count             205
# unique              7
# top              four
# freq              159

# %%
import seaborn as sns
plt.figure(figsize=(10,6))
sns.regplot(x="enginesize", y="price", data=dataTrain)
# Out:
# <AxesSubplot:xlabel='enginesize', ylabel='price'>

# %%
from scipy import stats
pearson_coef, p_value = stats.pearsonr(dataTrain['boreratio'], dataTrain['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.5531732367984435  with a P-value of P = 7.907922278249421e-18

# %%
import seaborn as sns
plt.figure(figsize=(10,6))
sns.regplot(x="symboling", y="price", data=dataTrain)
# Out:
# <AxesSubplot:xlabel='symboling', ylabel='price'>

# %%
p_value = stats.pearsonr(dataTrain['symboling'], dataTrain['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.5531732367984435  with a P-value of P = (-0.0799782246427035, 0.25431175848636883)

# %%
plt.figure(figsize=(10,6))
sns.regplot(x="boreratio", y="price", data=dataTrain)
# Out:
# <AxesSubplot:xlabel='boreratio', ylabel='price'>

# %%
pearson_coef, p_value = stats.pearsonr(dataTrain['boreratio'], dataTrain['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.5531732367984435  with a P-value of P = 7.907922278249421e-18

# %%
plt.figure(figsize=(10,6))
sns.regplot(x="stroke", y="price", data=dataTrain)
# Out:
# <AxesSubplot:xlabel='stroke', ylabel='price'>

# %%
pearson_coef, p_value = stats.pearsonr(dataTrain['stroke'], dataTrain['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.07944308388193096  with a P-value of P = 0.2575137159091036

# %%
plt.figure(figsize=(10,6))
sns.regplot(x="curbweight", y="price", data=dataTrain)
# Out:
# <AxesSubplot:xlabel='curbweight', ylabel='price'>

# %%
pearson_coef, p_value = stats.pearsonr(dataTrain['curbweight'], dataTrain['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.8353048793372966  with a P-value of P = 1.2144448264032206e-54

# %%
plt.figure(figsize=(10,6))
sns.regplot(x="wheelbase", y="price", data=dataTrain)
# Out:
# <AxesSubplot:xlabel='wheelbase', ylabel='price'>

# %%
pearson_coef, p_value = stats.pearsonr(dataTrain['wheelbase'], dataTrain['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.5778155982921501  with a P-value of P = 1.1828204863377837e-19

# %%
plt.figure(figsize=(10,6))
sns.regplot(x="carwidth", y="price", data=dataTrain)
# Out:
# <AxesSubplot:xlabel='carwidth', ylabel='price'>

# %%
plt.figure(figsize=(10,6))
sns.regplot(x="carheight", y="price", data=dataTrain)
# Out:
# <AxesSubplot:xlabel='carheight', ylabel='price'>

# %%
pearson_coef, p_value = stats.pearsonr(dataTrain['carheight'], dataTrain['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.11933622657049445  with a P-value of P = 0.08832832352275669

# %%
plt.figure(figsize=(10,6))
sns.regplot(x="compressionratio", y="price", data=dataTrain)
# Out:
# <AxesSubplot:xlabel='compressionratio', ylabel='price'>

# %%
pearson_coef, p_value = stats.pearsonr(dataTrain['compressionratio'], dataTrain['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.06798350579944264  with a P-value of P = 0.3327723612238307

# %%
plt.figure(figsize=(10,6))
sns.regplot(x="boreratio", y="price", data=dataTrain)
# Out:
# <AxesSubplot:xlabel='boreratio', ylabel='price'>

# %%
pearson_coef, p_value = stats.pearsonr(dataTrain['boreratio'], dataTrain['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.5531732367984435  with a P-value of P = 7.907922278249421e-18

# %%
plt.figure(figsize=(10,6))
sns.regplot(x="carlength", y="price", data=dataTrain)
# Out:
# <AxesSubplot:xlabel='carlength', ylabel='price'>

# %%
pearson_coef, p_value = stats.pearsonr(dataTrain['carlength'], dataTrain['price'])
print("The Pearson Correlation Coefficient is", pearson_coef, " with a P-value of P =", p_value)
# Out:
# The Pearson Correlation Coefficient is 0.6829200156779621  with a P-value of P = 1.678706624074708e-29

# %%
plt.figure(figsize=(10,6))
sns.boxplot(x="carbody", y="price", data=dataTrain)
# Out:
# <AxesSubplot:xlabel='carbody', ylabel='price'>

# %%
sns.boxplot(x="fueltype", y="price", data=dataTrain)
# Out:
# <AxesSubplot:xlabel='fueltype', ylabel='price'>

# %%
sns.boxplot(x="drivewheel", y="price", data=dataTrain)
# Out:
# <AxesSubplot:xlabel='drivewheel', ylabel='price'>

# %%
sns.boxplot(x="cylindernumber", y="price", data=dataTrain)
# Out:
# <AxesSubplot:xlabel='cylindernumber', ylabel='price'>

# %%
sns.boxplot(x="enginelocation", y="price", data=dataTrain)
# Out:
# <AxesSubplot:xlabel='enginelocation', ylabel='price'>

# %%
sns.boxplot(x="symboling", y="price", data=dataTrain)
# Out:
# <AxesSubplot:xlabel='symboling', ylabel='price'>

# %%
from sklearn.preprocessing import LabelEncoder

labelencoder = LabelEncoder()
dataTrain.CarName = labelencoder.fit_transform(dataTrain.CarName)
dataTrain.fueltype = labelencoder.fit_transform(dataTrain.fueltype)
dataTrain.drivewheel = labelencoder.fit_transform(dataTrain.drivewheel)
dataTrain.enginelocation = labelencoder.fit_transform(dataTrain.enginelocation)

dataTrain.carlength = labelencoder.fit_transform(dataTrain.carlength)
dataTrain.curbweight = labelencoder.fit_transform(dataTrain.curbweight)
dataTrain.boreratio = labelencoder.fit_transform(dataTrain.boreratio)
dataTrain.stroke = labelencoder.fit_transform(dataTrain.stroke)
dataTrain.carbody = labelencoder.fit_transform(dataTrain.carbody)
dataTrain.enginetype = labelencoder.fit_transform(dataTrain.enginetype)
dataTrain.cylindernumber = labelencoder.fit_transform(dataTrain.cylindernumber)

# %%
dataTrain.head(10)
# Out:
#    symboling  CarName  fueltype  carbody  drivewheel  enginelocation  \
# 0          3        2         1        0           2               0
# 1          3        3         1        0           2               0
# 2          1        1         1        2           2               0
# 3          2        4         1        3           1               0
# 4          2        5         1        3           0               0
# 5          2        9         1        3           1               0
# 6          1        5         1        3           1               0
# 7          1        7         1        4           1               0
# 8          1        6         1        3           1               0
# 9          0        8         1        2           0               0
#
#    wheelbase  carlength  carwidth  carheight  curbweight  enginetype  \
# 0       88.6         22      64.1       48.8          92           0
# 1       88.6         22      64.1       48.8          92           0
# 2       94.5         29      65.5       52.4         115           5
# 3       99.8         45      66.2       54.3          66           3
# 4       99.4         45      66.4       54.3         116           3
# 5       99.8         47      66.3       53.1          87           3
# 6      105.8         67      71.4       55.7         118           3
# 7      105.8         67      71.4       55.7         126           3
# 8      105.8         67      71.4       55.9         142           3
# 9       99.5         49      67.9       52.0         136           3
#
#    cylindernumber  enginesize  boreratio  stroke  compressionratio  \
# 0               2         130         23       4               9.0
# 1               2         130         23       4               9.0
# 2               3         152          1      28               9.0
# 3               2         109         13      25              10.0
# 4               1         136         13      25               8.0
# 5               1         136         13      25               8.5
# 6               1         136         13      25               8.5
# 7               1         136         13      25               8.5
# 8               1         131         10      25               8.3
# 9               1         131         10      25               7.0
#
#    horsepower      price
# 0         111  13495.000
# 1         111  16500.000
# 2         154  16500.000
# 3         102  13950.000
# 4         115  17450.000
# 5         110  15250.000
# 6         110  17710.000
# 7         110  18920.000
# 8         140  23875.000
# 9         160  17859.167

# %%
# Calculate the z-score from with scipy
import scipy.stats as stats
dataTrain = stats.zscore(dataTrain)

# %%
dataTrain
# Out:
#      symboling   CarName  fueltype   carbody  drivewheel  enginelocation  \
# 0     1.743470 -1.838221  0.328798 -3.050975    1.213330       -0.121867
# 1     1.743470 -1.813780  0.328798 -3.050975    1.213330       -0.121867
# 2     0.133509 -1.862662  0.328798 -0.717207    1.213330       -0.121867
# 3     0.938490 -1.789339  0.328798  0.449677   -0.589081       -0.121867
# 4     0.938490 -1.764897  0.328798  0.449677   -2.391492       -0.121867
# ..         ...       ...       ...       ...         ...             ...
# 200  -1.476452  1.510231  0.328798  0.449677    1.213330       -0.121867
# 201  -1.476452  1.485790  0.328798  0.449677    1.213330       -0.121867
# 202  -1.476452  1.534673  0.328798  0.449677    1.213330       -0.121867
# 203  -1.476452  1.583555 -3.041381  0.449677    1.213330       -0.121867
# 204  -1.476452  1.607996  0.328798  0.449677    1.213330       -0.121867
#
#      wheelbase  carlength  carwidth  carheight  curbweight  enginetype  \
# 0    -1.690772  -0.652539 -0.844782  -2.020417    0.203460   -2.865105
# 1    -1.690772  -0.652539 -0.844782  -2.020417    0.203460   -2.865105
# 2    -0.708596  -0.320602 -0.190566  -0.543527    0.671647    1.886890
# 3     0.173698   0.438110  0.136542   0.235942   -0.325795   -0.013908
# 4     0.107110   0.438110  0.230001   0.235942    0.692003   -0.013908
# ..         ...        ...       ...        ...         ...         ...
# 200   1.721873   1.291662  1.398245   0.728239    0.875207   -0.013908
# 201   1.721873   1.291662  1.351515   0.728239    1.078766   -0.013908
# 202   1.721873   1.291662  1.398245   0.728239    0.956631    1.886890
# 203   1.721873   1.291662  1.398245   0.728239    1.404462   -0.013908
# 204   1.721873   1.291662  1.398245   0.728239    1.160190   -0.013908
#
#      cylindernumber  enginesize  boreratio    stroke  compressionratio  \
# 0         -0.147475    0.074449   0.509085 -1.756197         -0.288349
# 1         -0.147475    0.074449   0.509085 -1.756197         -0.288349
# 2          1.112210    0.604046  -1.698580  0.915569         -0.288349
# 3         -0.147475   -0.431076  -0.494399  0.581598         -0.035973
# 4         -1.407161    0.218885  -0.494399  0.581598         -0.540725
# ..              ...         ...        ...       ...               ...
# 200       -0.147475    0.339248   1.713265 -0.531638         -0.162161
# 201       -0.147475    0.339248   1.713265 -0.531638         -0.364062
# 202        1.112210    1.109571   0.810130 -1.422227         -0.338824
# 203        1.112210    0.435538  -1.196838  0.581598          3.244916
# 204       -0.147475    0.339248   1.713265 -0.531638         -0.162161
#
#      horsepower     price
# 0      0.174483  0.027391
# 1      0.174483  0.404461
# 2      1.264536  0.404461
# 3     -0.053668  0.084485
# 4      0.275883  0.523668
# ..          ...       ...
# 200    0.250533  0.447752
# 201    1.416637  0.723810
# 202    0.757535  1.029983
# 203    0.047732  1.153582
# 204    0.250533  1.173031
#
# [205 rows x 19 columns]

# %%
x_train=dataTrain.iloc[:,0:17]
y_train=dataTrain.iloc[:,18]

# %%
#In case you have no separate testing data, use the following code
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test = train_test_split(x_train, y_train, test_size = 0.3, random_state = 0)
#30% of the trainng data will be used for testing

# %%
x_train.head()
# Out:
#      symboling   CarName  fueltype   carbody  drivewheel  enginelocation  \
# 40   -0.671472 -1.007218  0.328798  0.449677   -0.589081       -0.121867
# 60   -0.671472 -0.493952  0.328798  0.449677   -0.589081       -0.121867
# 56    1.743470 -0.567276  0.328798 -0.717207    1.213330       -0.121867
# 101  -0.671472 -0.151774  0.328798  0.449677   -0.589081       -0.121867
# 86    0.133509 -0.200657  0.328798  0.449677   -0.589081       -0.121867
#
#      wheelbase  carlength  carwidth  carheight  curbweight  enginetype  \
# 40   -0.375655   0.248432 -1.592458   0.153893   -0.244371   -0.013908
# 60    0.007227   0.580369  0.276731   0.728239   -0.122235   -0.013908
# 56   -0.575419  -0.557700 -0.097107  -1.692220   -0.224015    2.837289
# 101   0.273580   0.912306  0.276731   0.564140    1.241614    1.886890
# 86   -0.408949  -0.178344 -0.237296  -0.871725   -0.142591   -0.013908
#
#      cylindernumber  enginesize  boreratio    stroke  compressionratio
# 40        -0.147475   -0.407003  -0.695096  1.360863         -0.288349
# 60        -0.147475   -0.118132   0.208039  0.470274         -0.389299
# 56         4.891266   -1.369907  -0.093006  0.024980         -0.187398
# 101        1.112210    1.302152   0.308388  0.136304         -0.288349
# 86        -0.147475   -0.118132   0.107691  0.804245         -0.414537

# %%
y_train.head()
# Out:
# 40    -0.374148
# 60    -0.600013
# 56    -0.179652
# 101    0.027893
# 86    -0.638410
# Name: price, dtype: float64

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model_mlr = model.fit(x_train,y_train)

# %%
y_pred1 = model_mlr.predict(x_test)

# %%
y_test.iloc[0]
# Out:
# -0.8133305542770796

# %%
y_pred1[0]
# Out:
# -0.7237850021249268

# %%
from sklearn.metrics import mean_squared_error,mean_absolute_error
mse1 = mean_squared_error(y_test, y_pred1)
print('The mean square error for Multiple Linear Regression: ', mse1)
# Out:
# The mean square error for Multiple Linear Regression:  0.15952783313096133

# %%
from sklearn.ensemble import RandomForestRegressor
rf = RandomForestRegressor()
model_rf = rf.fit(x_train,y_train)

# %%
y_pred1 = model_mlr.predict(x_test)

# %%
#randomly checking the y-test values
y_test.iloc[0]
# Out:
# -0.8133305542770796

# %%
y_pred1[0]
# Out:
# -0.7237850021249268

# %%
mse1 = mean_squared_error(y_test, y_pred1)
print('The mean square error for Multiple Linear Regression: ', mse1)
# Out:
# The mean square error for Multiple Linear Regression:  0.15952783313096133

# %%
mae1= mean_absolute_error(y_test, y_pred1)
print('The mean absolute error for Multiple Linear Regression: ', mae1)
# Out:
# The mean absolute error for Multiple Linear Regression:  0.2721411417360212

# %%
rf = RandomForestRegressor()
model_rf = rf.fit(x_train,y_train)

# %%
y_pred2 = model_rf.predict(x_test)

# %%
mse2 = mean_squared_error(y_test, y_pred2)
print('The mean square error of price and predicted value is: ', mse2)
# Out:
# The mean square error of price and predicted value is:  0.09355245429811458

# %%
mae2= mean_absolute_error(y_test, y_pred2)
print('The mean absolute error of price and predicted value is: ', mae2)
# Out:
# The mean absolute error of price and predicted value is:  0.21146350630206687

# %%
from sklearn.linear_model import LinearRegression,Lasso
LassoModel = Lasso()
model_lm = LassoModel.fit(x_train,y_train)

# %%
y_pred2 = model_rf.predict(x_test)

# %%
y_pred3 = model_lm.predict(x_test)

# %%
mae3= mean_absolute_error(y_test, y_pred3)
print('The mean absolute error of price and predicted value is: ', mae3)
# Out:
# The mean absolute error of price and predicted value is:  0.7435800329998522

# %%
mse3 = mean_squared_error(y_test, y_pred3)
print('The mean square error of price and predicted value is: ', mse3)
# Out:
# The mean square error of price and predicted value is:  1.0398785219798534

# %%
scores = [('MLR', mae1),
          ('Random Forest', mae2),
          ('LASSO', mae3)
         ]

# %%
mae = pd.DataFrame(data = scores, columns=['Model', 'MAE Score'])
mae
# Out:
#            Model  MAE Score
# 0            MLR   0.272141
# 1  Random Forest   0.211464
# 2          LASSO   0.743580

# %%
import seaborn as sns
import matplotlib.pyplot as plt
mae.sort_values(by=(['MAE Score']), ascending=False, inplace=True)

f, axe = plt.subplots(1,1, figsize=(10,7))
sns.barplot(x = mae['Model'], y=mae['MAE Score'], ax = axe)
axe.set_xlabel('Model', size=20)
axe.set_ylabel('Mean Absolute Error', size=20)

plt.show()
